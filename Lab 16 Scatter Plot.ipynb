# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Scatter Plot**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# ## Overview
#
# In this lab, you will focus on creating and interpreting scatter plots to visualize relationships between variables and trends in the dataset. The provided dataset will be directly loaded into a pandas DataFrame, and various scatter plot-related visualizations will be created to explore developer trends, compensation, and preferences.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will:
#
# - Create and analyze scatter plots to examine relationships between variables.
#
# - Use scatter plots to identify trends and patterns in the dataset.
#
# - Focus on visualizations centered on scatter plots for better data-driven insights.

# %% [markdown]
# ## Setup: Working with the Database

# %% [markdown]
# **Install and import the required libraries**

# %%
# !pip install pandas
# !pip install matplotlib

import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.2.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.2)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 117.2 MB/s eta 0:00:00
# Downloading numpy-2.2.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 171.9 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-2.2.5 pandas-2.2.3 tzdata-2025.2
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.57.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (102 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 93.3 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 135.8 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 78.8 MB/s eta 0:00:00
# Downloading pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 135.1 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.57.0 kiwisolver-1.4.8 matplotlib-3.10.1 pillow-11.2.1 pyparsing-3.2.3

# %% [markdown]
# #### Step 1: Load the dataset

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"

df = pd.read_csv(file_path)

# %% [markdown]
# ### Task 1: Exploring Relationships with Scatter Plots

# %% [markdown]
# #### 1. Scatter Plot for Age vs. Job Satisfaction

# %% [markdown]
# Visualize the relationship between respondents' age (`Age`) and job satisfaction (`JobSatPoints_6`). Use this plot to identify any patterns or trends.

# %%
## Write your code here
# !pip install seaborn

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.regplot(
    data=df,
    x='Age',
    y='JobSatPoints_6',
    scatter_kws={'alpha': 0.5, 'color': 'dodgerblue'},
    line_kws={'color': 'darkorange'}
)

plt.title('Age vs. Job Satisfaction (JobSatPoints_6)')
plt.xlabel('Age')
plt.ylabel('Job Satisfaction (6-point scale)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.12/site-packages (from seaborn) (2.2.5)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/conda/lib/python3.12/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[6], line 8
#       5 import matplotlib.pyplot as plt
#       7 plt.figure(figsize=(10, 6))
# ----> 8 sns.regplot(
#       9     data=df,
#      10     x='Age',
#      11     y='JobSatPoints_6',
#      12     scatter_kws={'alpha': 0.5, 'color': 'dodgerblue'},
#      13     line_kws={'color': 'darkorange'}
#      14 )
#      16 plt.title('Age vs. Job Satisfaction (JobSatPoints_6)')
#      17 plt.xlabel('Age')
#
# File /opt/conda/lib/python3.12/site-packages/seaborn/regression.py:775, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     773 scatter_kws["marker"] = marker
#     774 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 775 plotter.plot(ax, scatter_kws, line_kws)
#     776 return ax
#
# File /opt/conda/lib/python3.12/site-packages/seaborn/regression.py:384, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
#     381     self.scatterplot(ax, scatter_kws)
#     383 if self.fit_reg:
# --> 384     self.lineplot(ax, line_kws)
#     386 # Label the axes
#     387 if hasattr(self.x, "name"):
#
# File /opt/conda/lib/python3.12/site-packages/seaborn/regression.py:429, in _RegressionPlotter.lineplot(self, ax, kws)
#     427 """Draw the model."""
#     428 # Fit the regression model
# --> 429 grid, yhat, err_bands = self.fit_regression(ax)
#     430 edges = grid[0], grid[-1]
#     432 # Get set default aesthetics
#
# File /opt/conda/lib/python3.12/site-packages/seaborn/regression.py:209, in _RegressionPlotter.fit_regression(self, ax, x_range, grid)
#     207         else:
#     208             x_min, x_max = ax.get_xlim()
# --> 209     grid = np.linspace(x_min, x_max, 100)
#     210 ci = self.ci
#     212 # Fit the regression
#
# File /opt/conda/lib/python3.12/site-packages/numpy/_core/function_base.py:130, in linspace(start, stop, num, endpoint, retstep, dtype, axis, device)
#     128 conv = _array_converter(start, stop)
#     129 start, stop = conv.as_arrays()
# --> 130 dt = conv.result_type(ensure_inexact=True)
#     132 if dtype is None:
#     133     dtype = dt
#
# DTypePromotionError: The DType <class 'numpy.dtypes._PyFloatDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy.dtypes.StrDType'>, <class 'numpy.dtypes.StrDType'>, <class 'numpy.dtypes._PyFloatDType'>)

# %% [markdown]
# #### 2. Scatter Plot for Compensation vs. Job Satisfaction

# %% [markdown]
# Explore the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`) using a scatter plot.

# %%
## Write your code here
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df,
    x='ConvertedCompYearly',
    y='JobSatPoints_6',
    alpha=0.5,
    color='mediumseagreen'
)

plt.title('Yearly Compensation vs. Job Satisfaction')
plt.xlabel('Yearly Compensation (USD)')
plt.ylabel('Job Satisfaction (6-point scale)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 2: Enhancing Scatter Plots

# %% [markdown]
# #### 1. Scatter Plot with Trend Line for Age vs. Job Satisfaction

# %% [markdown]
# Add a regression line to the scatter plot of Age vs. JobSatPoints_6 to highlight trends in the data.

# %%
## Write your code here
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.regplot(
    data=df,
    x='Age',
    y='JobSatPoints_6',
    scatter_kws={'alpha': 0.5, 'color': 'skyblue'},
    line_kws={'color': 'darkblue', 'linewidth': 2}
)

plt.title('Age vs. Job Satisfaction with Trend Line')
plt.xlabel('Age')
plt.ylabel('Job Satisfaction (6-point scale)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[8], line 6
#       3 import matplotlib.pyplot as plt
#       5 plt.figure(figsize=(10, 6))
# ----> 6 sns.regplot(
#       7     data=df,
#       8     x='Age',
#       9     y='JobSatPoints_6',
#      10     scatter_kws={'alpha': 0.5, 'color': 'skyblue'},
#      11     line_kws={'color': 'darkblue', 'linewidth': 2}
#      12 )
#      14 plt.title('Age vs. Job Satisfaction with Trend Line')
#      15 plt.xlabel('Age')
#
# File /opt/conda/lib/python3.12/site-packages/seaborn/regression.py:775, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     773 scatter_kws["marker"] = marker
#     774 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 775 plotter.plot(ax, scatter_kws, line_kws)
#     776 return ax
#
# File /opt/conda/lib/python3.12/site-packages/seaborn/regression.py:384, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
#     381     self.scatterplot(ax, scatter_kws)
#     383 if self.fit_reg:
# --> 384     self.lineplot(ax, line_kws)
#     386 # Label the axes
#     387 if hasattr(self.x, "name"):
#
# File /opt/conda/lib/python3.12/site-packages/seaborn/regression.py:429, in _RegressionPlotter.lineplot(self, ax, kws)
#     427 """Draw the model."""
#     428 # Fit the regression model
# --> 429 grid, yhat, err_bands = self.fit_regression(ax)
#     430 edges = grid[0], grid[-1]
#     432 # Get set default aesthetics
#
# File /opt/conda/lib/python3.12/site-packages/seaborn/regression.py:209, in _RegressionPlotter.fit_regression(self, ax, x_range, grid)
#     207         else:
#     208             x_min, x_max = ax.get_xlim()
# --> 209     grid = np.linspace(x_min, x_max, 100)
#     210 ci = self.ci
#     212 # Fit the regression
#
# File /opt/conda/lib/python3.12/site-packages/numpy/_core/function_base.py:130, in linspace(start, stop, num, endpoint, retstep, dtype, axis, device)
#     128 conv = _array_converter(start, stop)
#     129 start, stop = conv.as_arrays()
# --> 130 dt = conv.result_type(ensure_inexact=True)
#     132 if dtype is None:
#     133     dtype = dt
#
# DTypePromotionError: The DType <class 'numpy.dtypes._PyFloatDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy.dtypes.StrDType'>, <class 'numpy.dtypes.StrDType'>, <class 'numpy.dtypes._PyFloatDType'>)

# %% [markdown]
# #### 2. Scatter Plot for Age vs. Work Experience

# %% [markdown]
# Visualize the relationship between Age (`Age`) and Work Experience (`YearsCodePro`) using a scatter plot.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df,
    x='Age',
    y='YearsCodePro',
    color='slateblue',
    alpha=0.6
)

plt.title('Age vs. Professional Coding Experience')
plt.xlabel('Age')
plt.ylabel('Years of Professional Coding Experience')
plt.grid(True)
plt.tight_layout()
plt.show()
## Write your code here

# %% [markdown]
# ### Task 3: Combining Scatter Plots with Additional Features

# %% [markdown]
# #### 1. Bubble Plot of Compensation vs. Job Satisfaction with Age as Bubble Size

# %% [markdown]
# Create a bubble plot to explore the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`), with bubble size representing age.

# %%
import matplotlib.pyplot as plt

# Step 1: Filter out rows with missing or extreme values
bubble_df = df[['ConvertedCompYearly', 'JobSatPoints_6', 'Age']].dropna()
bubble_df = bubble_df[bubble_df['ConvertedCompYearly'] < 300000]  # optional salary cap

# Step 2: Create the bubble plot
plt.figure(figsize=(12, 7))
plt.scatter(
    x=bubble_df['ConvertedCompYearly'],
    y=bubble_df['JobSatPoints_6'],
    s=bubble_df['Age'] * 2,               # bubble size
    c=bubble_df['Age'],                   # bubble color
    cmap='coolwarm',
    alpha=0.5,
    edgecolors='w',
    linewidth=0.5
)

plt.title('Bubble Plot: Compensation vs. Job Satisfaction (Bubble Size = Age)')
plt.xlabel('Yearly Compensation (USD)')
plt.ylabel('Job Satisfaction (6-point scale)')
plt.colorbar(label='Age')  # shows bubble color scale
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 9
#       7 # Step 2: Create the bubble plot
#       8 plt.figure(figsize=(12, 7))
# ----> 9 plt.scatter(
#      10     x=bubble_df['ConvertedCompYearly'],
#      11     y=bubble_df['JobSatPoints_6'],
#      12     s=bubble_df['Age'] * 2,               # bubble size
#      13     c=bubble_df['Age'],                   # bubble color
#      14     cmap='coolwarm',
#      15     alpha=0.5,
#      16     edgecolors='w',
#      17     linewidth=0.5
#      18 )
#      20 plt.title('Bubble Plot: Compensation vs. Job Satisfaction (Bubble Size = Age)')
#      21 plt.xlabel('Yearly Compensation (USD)')
#
# File /opt/conda/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/matplotlib/pyplot.py:3937, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3917 @_copy_docstring_and_deprecators(Axes.scatter)
#    3918 def scatter(
#    3919     x: float | ArrayLike,
#    (...)
#    3935     **kwargs,
#    3936 ) -> PathCollection:
# -> 3937     __ret = gca().scatter(
#    3938         x,
#    3939         y,
#    3940         s=s,
#    3941         c=c,
#    3942         marker=marker,
#    3943         cmap=cmap,
#    3944         norm=norm,
#    3945         vmin=vmin,
#    3946         vmax=vmax,
#    3947         alpha=alpha,
#    3948         linewidths=linewidths,
#    3949         edgecolors=edgecolors,
#    3950         colorizer=colorizer,
#    3951         plotnonfinite=plotnonfinite,
#    3952         **({"data": data} if data is not None else {}),
#    3953         **kwargs,
#    3954     )
#    3955     sci(__ret)
#    3956     return __ret
#
# File /opt/conda/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File /opt/conda/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4939, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4935 s = np.ma.ravel(s)
#    4936 if (len(s) not in (1, x.size) or
#    4937         (not np.issubdtype(s.dtype, np.floating) and
#    4938          not np.issubdtype(s.dtype, np.integer))):
# -> 4939     raise ValueError(
#    4940         "s must be a scalar, "
#    4941         "or float array-like with the same size as x and y")
#    4943 # get the original edgecolor the user passed before we normalize
#    4944 orig_edgecolor = edgecolors
#
# ValueError: s must be a scalar, or float array-like with the same size as x and y

# %% [markdown]
# #### 2. Scatter Plot for Popular Programming Languages by Job Satisfaction

# %% [markdown]
# Visualize the popularity of programming languages (`LanguageHaveWorkedWith`) against job satisfaction using a scatter plot. Use points to represent satisfaction levels for each language.

# %%
## Write your code here

# %% [markdown]
# ### Task 4: Scatter Plot Comparisons Across Groups

# %% [markdown]
# #### 1. Scatter Plot for Compensation vs. Job Satisfaction by Employment Type

# %% [markdown]
# Visualize the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`), categorized by employment type (`Employment`). Use color coding or markers to differentiate between employment types.

# %%
## Write your code here
import matplotlib.pyplot as plt

# Optional: filter out outlier salaries for better visualization
filtered_df = df[df['ConvertedCompYearly'] < 300000]

plt.figure(figsize=(12, 7))
plt.scatter(
    filtered_df['ConvertedCompYearly'],
    filtered_df['JobSatPoints_6'],
    s=filtered_df['Age'] * 2,  # Bubble size scaled by age
    alpha=0.5,
    c=filtered_df['Age'],      # Optional: color by age
    cmap='viridis',
    edgecolors='w',
    linewidth=0.5
)

plt.title('Bubble Plot: Compensation vs. Job Satisfaction (Bubble Size = Age)')
plt.xlabel('Yearly Compensation (USD)')
plt.ylabel('Job Satisfaction (6-point scale)')
plt.colorbar(label='Age')  # shows age color scale
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 8
#       5 filtered_df = df[df['ConvertedCompYearly'] < 300000]
#       7 plt.figure(figsize=(12, 7))
# ----> 8 plt.scatter(
#       9     filtered_df['ConvertedCompYearly'],
#      10     filtered_df['JobSatPoints_6'],
#      11     s=filtered_df['Age'] * 2,  # Bubble size scaled by age
#      12     alpha=0.5,
#      13     c=filtered_df['Age'],      # Optional: color by age
#      14     cmap='viridis',
#      15     edgecolors='w',
#      16     linewidth=0.5
#      17 )
#      19 plt.title('Bubble Plot: Compensation vs. Job Satisfaction (Bubble Size = Age)')
#      20 plt.xlabel('Yearly Compensation (USD)')
#
# File /opt/conda/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/matplotlib/pyplot.py:3937, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3917 @_copy_docstring_and_deprecators(Axes.scatter)
#    3918 def scatter(
#    3919     x: float | ArrayLike,
#    (...)
#    3935     **kwargs,
#    3936 ) -> PathCollection:
# -> 3937     __ret = gca().scatter(
#    3938         x,
#    3939         y,
#    3940         s=s,
#    3941         c=c,
#    3942         marker=marker,
#    3943         cmap=cmap,
#    3944         norm=norm,
#    3945         vmin=vmin,
#    3946         vmax=vmax,
#    3947         alpha=alpha,
#    3948         linewidths=linewidths,
#    3949         edgecolors=edgecolors,
#    3950         colorizer=colorizer,
#    3951         plotnonfinite=plotnonfinite,
#    3952         **({"data": data} if data is not None else {}),
#    3953         **kwargs,
#    3954     )
#    3955     sci(__ret)
#    3956     return __ret
#
# File /opt/conda/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File /opt/conda/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4939, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4935 s = np.ma.ravel(s)
#    4936 if (len(s) not in (1, x.size) or
#    4937         (not np.issubdtype(s.dtype, np.floating) and
#    4938          not np.issubdtype(s.dtype, np.integer))):
# -> 4939     raise ValueError(
#    4940         "s must be a scalar, "
#    4941         "or float array-like with the same size as x and y")
#    4943 # get the original edgecolor the user passed before we normalize
#    4944 orig_edgecolor = edgecolors
#
# ValueError: s must be a scalar, or float array-like with the same size as x and y

# %% [markdown]
# #### 2. Scatter Plot for Work Experience vs. Age Group by Country

# %% [markdown]
# Compare work experience (`YearsCodePro`) across different age groups (`Age`) and countries (`Country`). Use colors to represent different countries and markers for age groups.

# %%
## Write your code here

# %% [markdown]
# ### Final Step: Review

# %% [markdown]
# With these scatter plots, you will have analyzed data relationships across multiple dimensions, including compensation, job satisfaction, employment types, and demographics, to uncover meaningful trends in the developer community.

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Analyze how numerical variables relate across specific groups, such as employment types and countries.
# - Use scatter plots effectively to represent multiple variables with color, size, and markers.
# - Gain insights into compensation, satisfaction, and demographic trends using advanced scatter plot techniques.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-07|1.2|Madhusudan Moole|Reviewed and updated lab|
# |2024-10-06|1.0|Raghul Ramesh|Created lab|-->

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
